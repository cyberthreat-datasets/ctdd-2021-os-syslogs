# %%
import sys
sys.path.insert(1, '../Source_Code')

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
import numpy as np
import importlib
import pandas as pd
import seaborn
from IPython.display import Image
import matplotlib.pyplot as plt

import Transformer as tnsf
import preprocess as ad

import copy
from matplotlib.colors import LogNorm
np.set_printoptions(threshold=sys.maxsize)

importlib.reload(ad)
importlib.reload(tnsf)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#device = "cuda"
print(device)
# Out:
# cuda

# %%
def test_generate(name, window_size=10):
    hdfs = set()
    # hdfs = []
    with open( name, 'r') as f:
        for ln in f.readlines():
            ln = list(map(lambda n: n, map(int, ln.strip().split())))
#             ln = ln + [0] * (window_size + 1 - len(ln))
            hdfs.add(tuple(ln))
            # hdfs.append(tuple(ln))
    print('Number of sessions({}): {}'.format(name, len(hdfs)))
    return hdfs

# %%
importlib.reload(ad)
# Out:
# <module 'preprocess' from '../Source_Code/preprocess.py'>

# %%
def create_mat(dataloader, model, layers, heads, file, enc =True, dec = False):
    
    enc_att = np.zeros((449,449))
    enc_tp_att = np.zeros((449,449))
    enc_fn_att = np.zeros((449,449))
    
    if dec:
        dec_att = np.zeros((449,449))
        dec_tp_att = np.zeros((449,449))
        dec_fn_att = np.zeros((449,449))
    
    src_mask = Variable(torch.ones(1, 1, window_size + 1)).to(device)
    bos = torch.ones((1, ),dtype = int).to(device)
    
    print("********** ********** ********** ********** **********")
    print("      ********** FIRST INPUT SEQUENCE ********** ")
    print("********** ********** ********** ********** **********")
    print("\n")
    sequence_cnt = 10
    anomaly_timeline = []
    line_number = 1
    for line in dataloader:
        if line_number%25==0:
            print("Current Sequence Number:",line_number)
        else:
            pass
        line_number += 1
        for i in range(len(line) - window_size):
            seq = line[i:i + window_size]
            
            #for predicting 10
            label = line[i+window_size:(i+window_size)+window_size]
            
            #for predicting only 1
            ###label = line[i+window_size:(i+window_size)+1]
            ###print("Sequence: {}".format(seq))
            ###ad.backtrace(seq, "linux.log", "Spell")
            

            t1 = torch.cat((bos, torch.tensor(seq, dtype = torch.int).to(device))).unsqueeze(0)
            t2 = torch.tensor(label, dtype = torch.int).to(device).unsqueeze(0)

            src = Variable(t1, requires_grad =False)
            tgt = Variable(t2, requires_grad =False)

            print("---------- ---------- ---------- ---------- ----------")
            print("Input Sequence: {}".format(seq))
            print("Label: {}".format(label))
            print("\n")

#             print("~~~~~~~~~~ ATTENTION WEIGHTS ON GREEDY DECODE ~~~~~~~~~~")
#             print("\n")
            ###tgt_pred = tnsf.predict(model, src, src_mask, tgt, max_len = len(tgt)+1, start_symbol = 1, g = 10)
            ###tgt_pred = tnsf.greedy_decode(model, src, src_mask, tgt, len(label)+1, 1, True, g=10, halt = True, layers = layers, heads = heads)
            tgt_pred, candidates = tnsf.greedy_decode(model, src, src_mask, tgt, 2, 1, True, g=10, halt = True, layers = layers, heads = heads)

            # List for every deteected anomaly
            if tgt_pred.cpu().detach().numpy() in candidates.cpu().detach().numpy():
                anomaly_timeline.append(0)
            else:
                anomaly_timeline.append(1)
                
            ###print("---------- ---------- ---------- ---------- ----------")
            ###print("Input Sequence: {}".format(seq))
            ###print("Label: {}".format(label))
            ###print("Pred: {}".format(tgt_pred[0][0]))

            print("\n")
            print("~~~~~~~~~~ SEQUENCE BACKTRACE ~~~~~~~~~~")
            ad.backtrace(seq, "linux.log", "Spell")
            print("\n")
            print("~~~~~~~~~~ LABEL BACKTRACE ~~~~~~~~~~")
            ad.backtrace(label[:1], "linux.log", "Spell") 
            print("\n")
            print("~~~~~~~~~~ PREDICTION BACKTRACE [Top 4] ~~~~~~~~~~")
            ###ad.backtrace(tuple(tgt_pred.cpu().detach().numpy()[0]) , "linux.log", "Spell")
            ad.backtrace(tuple(np.flip(candidates.cpu().detach().numpy()[6:])) , "linux.log", "Spell")
            print("\n")
            
            enc_weights = 0
            
            for layer in range(layers):
                for h in range(heads):
                    ###print("Layer:{} , Head: {}".format(layer,h))
                    enc_weights += model.encoder.layers[layer].self_attn.attn[0, h].data[:len(label), 1:len(seq)+1][0]
                    ###print("~~~~~~~~~~ ENCODER ATTENTION WEIGHTS ~~~~~~~~~~")
                    ###print(enc_weights)
                    ###print("\n")
                    
            if dec:
                dec_weights = 0
                for layer in range(layers):
                    for h in range(heads):
                        ###print("Decoder Layer:{} , Head: {}".format(layer,h))                    
                        dec_weights += model.decoder.layers[layer].self_attn.attn[0, h].data[:len(label), :len(seq)][0]
                        ###if you are predicting 10 use the code below
                        ###dec_weights += model.decoder.layers[layer].self_attn.attn[0, h].data[:len(label), :len(seq)]
                        ###print("~~~~~~~~~~ DECODER ATTENTION WEIGHTS ~~~~~~~~~~")
                        ###print(dec_weights)
                        ###print("\n")
            
            print("########## END OF INFO FOR LOG SEQUENCE {} ##########".format(sequence_cnt))
            print("\n")
            print("\n")
            print("\n")

            sequence_cnt += 1
            
            print("********** ********** ********** ********** **********")
            print("     ********** INPUT SEQUENCE {} - {} **********".format(sequence_cnt-9,sequence_cnt))
            print("********** ********** ********** ********** **********")
            print("\n")
            
            ###print(label[0],tgt_pred.cpu().detach().numpy())
            ###print(label[0] in tgt_pred.cpu().detach().numpy())
            ###if label[0] not in tgt_pred.cpu().detach().numpy():
            ###    print(label[0],tgt_pred)
            ###else:
            ###    pass
            
            for i in range(len(tgt_pred)):
#             uncomment if you are using 10 predictions instead of 1
                for j in range(len(tgt_pred)):
                        enc_att[seq[i],label[j]] += enc_weights[i]  
#                 enc_att[seq[i], label[0]] += enc_weights[i]

            
            if -1 in tgt_pred:
                for i in range(len(tgt_pred)):
                #uncomment if you are using 10 predictions instead of 1
                    for j in range(len(tgt_pred)):
                        enc_tp_att[seq[i],label[j]] += enc_weights[i]
#                     enc_tp_att[seq[i],label[0]] += enc_weights[i]
            else:
                for i in range(len(tgt_pred)):
                #uncomment if you are using 10 predictions instead of 1
                    for j in range(len(tgt_pred)):
                        enc_fn_att[seq[i],label[j]] += enc_weights[i]    
#                     enc_fn_att[seq[i], label[0]] += enc_weights[i]
            
            if dec:
                for i in range(len(tgt_pred)):
                    for j in range(len(tgt_pred)):
                        dec_att[seq[i], label[j]] += dec_weights[i]

                if -1 in tgt_pred:
#                    print("halt")
                    for i in range(len(tgt_pred)):
                        for j in range(len(tgt_pred)):
                            dec_tp_att[seq[i],label[j]] += dec_weights[i]
                else:
                    for i in range(len(tgt_pred)):
                        for j in range(len(tgt_pred)):
                            dec_fn_att[seq[i], label[j]] += dec_weights[i]    
            

#     with open("Attention-Based_Weights/all_" + file + '_attention.npy', 'wb') as f:
#         np.save(f, enc_att)
                        
#     with open("Attention-Based_Weights/tp_" + file + '_attention.npy', 'wb') as f:
#         np.save(f, enc_tp_att)
        
#     with open("Attention-Based_Weights/fn_" + file + '_attention.npy', 'wb') as f:
#         np.save(f, enc_fn_att)        
    
    enc_att_normalized =(enc_att-np.min(enc_tp_att))/(np.max(enc_att)-np.min(enc_att))
    enc_tp_att_normalized =(enc_tp_att-np.min(enc_tp_att))/(np.max(enc_tp_att)-np.min(enc_tp_att))
    enc_fn_att_normalized =(enc_fn_att-np.min(enc_fn_att))/(np.max(enc_fn_att)-np.min(enc_fn_att))
#     print(enc_fn_att_normalized[enc_fn_att_normalized>0])
    if dec:
        dec_att_normalized =(dec_att-np.min(dec_tp_att))/(np.max(dec_att)-np.min(dec_att))
        dec_tp_att_normalized =(dec_tp_att-np.min(dec_tp_att))/(np.max(dec_tp_att)-np.min(dec_tp_att))
        dec_fn_att_normalized =(dec_fn_att-np.min(dec_fn_att))/(np.max(dec_fn_att)-np.min(dec_fn_att))

#     with open("Attention-Based_Weights/all_" + file + '_normalized_attention.npy', 'wb') as f:
#             np.save(f, enc_att_normalized)  
#     with open("Attention-Based_Weights/tp_" + file + '_normalized_attention.npy', 'wb') as f:
#             np.save(f, enc_tp_att_normalized)  
#     with open("Attention-Based_Weights/fn_" + file + '_normalized_attention.npy', 'wb') as f:
#             np.save(f, enc_fn_att_normalized)              

    # Plot Anomaly Detection Timeline
    fig = plt.figure(figsize = (15, 5))
    x = range(11,len(anomaly_timeline)+11)
    plt.xlabel("Log Timeline", fontsize=14)
    plt.ylabel("Anomaly = 1, Normal =0", fontsize=14)
    plt.title("Anomaly Detection Timelline", fontsize=14)
    plt.bar(x, anomaly_timeline, color = "blue")
    plt.xlim([11, len(anomaly_timeline)+11])
    #plt.setp(axs[1], yscale = 'log', xlabel="Log Key (Input Sequences)")
    plt.tight_layout()
    # plt.savefig('GonnaCry_bar_all.png')
    plt.show()        
            
#     return (enc_att_normalized, enc_tp_att_normalized, enc_fn_att_normalized), (dec_att_normalized, dec_tp_att_normalized, dec_fn_att_normalized)
    return (enc_att_normalized, enc_tp_att_normalized, enc_fn_att_normalized)

# %%
test_abnormal_loader = test_generate("../CTDD_Dataset/Sample_Cyber_Threat_Log_Keys/jy-ntp-ddos-amplification-atk-tool-t1498")
# Out:
# Number of sessions(../CTDD_Dataset/Sample_Cyber_Threat_Log_Keys/jy-ntp-ddos-amplification-atk-tool-t1498): 1

# %%
model = torch.load("../Saved_Models/global_models_practicum.pt")

# %%
# Model information
layers = 1
heads = 1
WINDOW_SIZE = 10
window_size = 10
importlib.reload(ad)
importlib.reload(tnsf)
# Out:
# <module 'Transformer' from '../Source_Code/Transformer.py'>

# %%
#print backtrack of logs
#tp att are for true positives
#fn att are for false negatives

att, tp_att, fn_att = create_mat(test_abnormal_loader, model, layers, heads, "ntp-ddos", enc=True, dec=False)
# Out:
# ********** ********** ********** ********** **********
#       ********** FIRST INPUT SEQUENCE **********
# ********** ********** ********** ********** **********
#
#
# ---------- ---------- ---------- ---------- ----------
# Input Sequence: (418, 258, 259, 224, 260, 260, 260, 260, 260, 260)
# Label: (260, 260, 263, 264, 264, 264, 164, 265, 266, 267)
#
#
# ^^^^^^^^^^ ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Candidate logs:  tensor([267, 149,  32, 164, 265, 264, 263,   7, 260,   8], device='cuda:0')
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Probabilities:  tf.Tensor([0.0303 0.0369 0.0421 0.0498 0.0633 0.0773 0.1108 0.1378 0.1679 0.2837], shape=(10,), dtype=float32)
#
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Encoder Attention Normalized [0.1559 0.1576 0.0381 0.1653 0.6889 0.0000 0.9487 0.8269 1.0000 0.4338]
#
#
#
#
# ~~~~~~~~~~ SEQUENCE BACKTRACE ~~~~~~~~~~
# 418 204    Starting Docker Application Container Engine...
# 258 159    time <*> <*>"" level info msg ""Starting up""
# 259 160    time <*> <*>"" level info msg ""detected <*> n...
# 224 112    [ <*>.<*>] audit type <*> audit <*>.<*> <*> <*>
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
#
#
# ~~~~~~~~~~ LABEL BACKTRACE ~~~~~~~~~~
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
#
#
# ~~~~~~~~~~ PREDICTION BACKTRACE [Top 4] ~~~~~~~~~~
# 8 2    Starting <*> Service...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 7 15    Network configuration changed trying to establ...
# 263 161    time <*> <*>"" level info msg ""[graphdriver] ...
#
#
# ########## END OF INFO FOR LOG SEQUENCE 10 ##########
#
#
#
#
#
#
# ********** ********** ********** ********** **********
#      ********** INPUT SEQUENCE 2 - 11 **********
# ********** ********** ********** ********** **********
#
#
# ---------- ---------- ---------- ---------- ----------
# Input Sequence: (258, 259, 224, 260, 260, 260, 260, 260, 260, 260)
# Label: (260, 263, 264, 264, 264, 164, 265, 266, 267, 268)
#
#
# ^^^^^^^^^^ ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Candidate logs:  tensor([265, 263,  17,  32,   5, 164, 264, 260,   8,   7], device='cuda:0')
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Probabilities:  tf.Tensor([0.0233 0.0298 0.0301 0.0327 0.0338 0.0350 0.1481 0.1609 0.1858 0.3206], shape=(10,), dtype=float32)
#
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Encoder Attention Normalized [0.3851 0.0494 0.3233 0.0000 0.7382 0.9766 1.0000 0.0000 0.9441 0.9827]
#
#
#
#
# ~~~~~~~~~~ SEQUENCE BACKTRACE ~~~~~~~~~~
# 258 159    time <*> <*>"" level info msg ""Starting up""
# 259 160    time <*> <*>"" level info msg ""detected <*> n...
# 224 112    [ <*>.<*>] audit type <*> audit <*>.<*> <*> <*>
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
#
#
# ~~~~~~~~~~ LABEL BACKTRACE ~~~~~~~~~~
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
#
#
# ~~~~~~~~~~ PREDICTION BACKTRACE [Top 4] ~~~~~~~~~~
# 7 15    Network configuration changed trying to establ...
# 8 2    Starting <*> Service...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 264 95    time <*> <*>"" level warning msg ""Your kernel...
#
#
# ########## END OF INFO FOR LOG SEQUENCE 11 ##########
#
#
#
#
#
#
# ********** ********** ********** ********** **********
#      ********** INPUT SEQUENCE 3 - 12 **********
# ********** ********** ********** ********** **********
#
#
# ---------- ---------- ---------- ---------- ----------
# Input Sequence: (259, 224, 260, 260, 260, 260, 260, 260, 260, 260)
# Label: (263, 264, 264, 264, 164, 265, 266, 267, 268, 269)
#
#
# ^^^^^^^^^^ ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Candidate logs:  tensor([267,  19, 265, 263, 164,  32,   8, 264, 260,   7], device='cuda:0')
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Probabilities:  tf.Tensor([0.0329 0.0359 0.0517 0.0520 0.0560 0.0839 0.1213 0.1635 0.1636 0.2393], shape=(10,), dtype=float32)
#
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Encoder Attention Normalized [0.0586 0.2001 0.3769 0.7881 0.4876 1.0000 0.4315 0.0000 0.5494 0.2945]
#
#
#
#
# ~~~~~~~~~~ SEQUENCE BACKTRACE ~~~~~~~~~~
# 259 160    time <*> <*>"" level info msg ""detected <*> n...
# 224 112    [ <*>.<*>] audit type <*> audit <*>.<*> <*> <*>
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
#
#
# ~~~~~~~~~~ LABEL BACKTRACE ~~~~~~~~~~
# 263 161    time <*> <*>"" level info msg ""[graphdriver] ...
#
#
# ~~~~~~~~~~ PREDICTION BACKTRACE [Top 4] ~~~~~~~~~~
# 7 15    Network configuration changed trying to establ...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 264 95    time <*> <*>"" level warning msg ""Your kernel...
# 8 2    Starting <*> Service...
#
#
# ########## END OF INFO FOR LOG SEQUENCE 12 ##########
#
#
#
#
#
#
# ********** ********** ********** ********** **********
#      ********** INPUT SEQUENCE 4 - 13 **********
# ********** ********** ********** ********** **********
#
#
# ---------- ---------- ---------- ---------- ----------
# Input Sequence: (224, 260, 260, 260, 260, 260, 260, 260, 260, 263)
# Label: (264, 264, 264, 164, 265, 266, 267, 268, 269, 270)
#
#
# ^^^^^^^^^^ ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Candidate logs:  tensor([ 11, 266, 265, 164,  19, 264,  17,   5,   7,   8], device='cuda:0')
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Probabilities:  tf.Tensor([0.0288 0.0299 0.0354 0.0372 0.0459 0.0551 0.0623 0.0701 0.0903 0.5451], shape=(10,), dtype=float32)
#
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Encoder Attention Normalized [0.1378 0.3236 0.6781 0.7612 1.0000 0.7522 0.5653 0.7589 0.0000 0.1999]
#
#
#
#
# ~~~~~~~~~~ SEQUENCE BACKTRACE ~~~~~~~~~~
# 224 112    [ <*>.<*>] audit type <*> audit <*>.<*> <*> <*>
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 263 161    time <*> <*>"" level info msg ""[graphdriver] ...
#
#
# ~~~~~~~~~~ LABEL BACKTRACE ~~~~~~~~~~
# 264 95    time <*> <*>"" level warning msg ""Your kernel...
#
#
# ~~~~~~~~~~ PREDICTION BACKTRACE [Top 4] ~~~~~~~~~~
# 8 2    Starting <*> Service...
# 7 15    Network configuration changed trying to establ...
# 5 8    ens3 DHCP lease lost
# 17 1    Could not set hostname Method call timed out
#
#
# ########## END OF INFO FOR LOG SEQUENCE 13 ##########
#
#
#
#
#
#
# ********** ********** ********** ********** **********
#      ********** INPUT SEQUENCE 5 - 14 **********
# ********** ********** ********** ********** **********
#
#
# ---------- ---------- ---------- ---------- ----------
# Input Sequence: (260, 260, 260, 260, 260, 260, 260, 260, 263, 264)
# Label: (264, 264, 164, 265, 266, 267, 268, 269, 270, 271)
#
#
# ^^^^^^^^^^ ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Candidate logs:  tensor([ 19, 267,  17,  11,   5,   3, 164, 265,  20, 264], device='cuda:0')
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Probabilities:  tf.Tensor([0.0377 0.0439 0.0459 0.0478 0.0535 0.0578 0.0615 0.0700 0.0719 0.5100], shape=(10,), dtype=float32)
#
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Encoder Attention Normalized [0.0000 0.0817 0.1499 0.1712 0.8038 0.4351 1.0000 0.5301 0.1801 0.1137]
#
#
#
#
# ~~~~~~~~~~ SEQUENCE BACKTRACE ~~~~~~~~~~
# ../Source_Code/Transformer.py:495: RuntimeWarning: invalid value encountered in true_divide
#   normalized_weights =(att-np.min(att))/(np.max(att)-np.min(att))
# ../Source_Code/Transformer.py:495: RuntimeWarning: invalid value encountered in true_divide
#   normalized_weights =(att-np.min(att))/(np.max(att)-np.min(att))
# ../Source_Code/Transformer.py:495: RuntimeWarning: invalid value encountered in true_divide
#   normalized_weights =(att-np.min(att))/(np.max(att)-np.min(att))
# ../Source_Code/Transformer.py:495: RuntimeWarning: invalid value encountered in true_divide
#   normalized_weights =(att-np.min(att))/(np.max(att)-np.min(att))
# ../Source_Code/Transformer.py:495: RuntimeWarning: invalid value encountered in true_divide
#   normalized_weights =(att-np.min(att))/(np.max(att)-np.min(att))
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 263 161    time <*> <*>"" level info msg ""[graphdriver] ...
# 264 95    time <*> <*>"" level warning msg ""Your kernel...
#
#
# ~~~~~~~~~~ LABEL BACKTRACE ~~~~~~~~~~
# 264 95    time <*> <*>"" level warning msg ""Your kernel...
#
#
# ~~~~~~~~~~ PREDICTION BACKTRACE [Top 4] ~~~~~~~~~~
# 264 95    time <*> <*>"" level warning msg ""Your kernel...
# 20 14    pcp CMD <*> -C
# 265 151    <*> <*> Bridge firewalling registered
# 164 107    time <*> <*>"" level info msg ""Loading contai...
#
#
# ########## END OF INFO FOR LOG SEQUENCE 14 ##########
#
#
#
#
#
#
# ********** ********** ********** ********** **********
#      ********** INPUT SEQUENCE 6 - 15 **********
# ********** ********** ********** ********** **********
#
#
# ---------- ---------- ---------- ---------- ----------
# Input Sequence: (260, 260, 260, 260, 260, 260, 260, 263, 264, 264)
# Label: (264, 164, 265, 266, 267, 268, 269, 270, 271, 164)
#
#
# ^^^^^^^^^^ ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Candidate logs:  tensor([  7,  19,  20,   5, 164,   3, 267,  16, 265, 264], device='cuda:0')
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Probabilities:  tf.Tensor([0.0432 0.0445 0.0493 0.0564 0.0783 0.0962 0.1189 0.1296 0.1363 0.2473], shape=(10,), dtype=float32)
#
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Encoder Attention Normalized [0.2039 0.5590 0.3020 0.5865 0.4778 0.4891 1.0000 0.0000 0.4579 0.2357]
#
#
#
#
# ~~~~~~~~~~ SEQUENCE BACKTRACE ~~~~~~~~~~
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 263 161    time <*> <*>"" level info msg ""[graphdriver] ...
# 264 95    time <*> <*>"" level warning msg ""Your kernel...
# 264 95    time <*> <*>"" level warning msg ""Your kernel...
#
#
# ~~~~~~~~~~ LABEL BACKTRACE ~~~~~~~~~~
# 264 95    time <*> <*>"" level warning msg ""Your kernel...
#
#
# ~~~~~~~~~~ PREDICTION BACKTRACE [Top 4] ~~~~~~~~~~
# 264 95    time <*> <*>"" level warning msg ""Your kernel...
# 265 151    <*> <*> Bridge firewalling registered
# 16 5    Failed to start <*>
# 267 145    <*> <*> Netfilter messages via NETLINK v0.<*>.
#
#
# ########## END OF INFO FOR LOG SEQUENCE 15 ##########
#
#
#
#
#
#
# ********** ********** ********** ********** **********
#      ********** INPUT SEQUENCE 7 - 16 **********
# ********** ********** ********** ********** **********
#
#
# ---------- ---------- ---------- ---------- ----------
# Input Sequence: (260, 260, 260, 260, 260, 260, 263, 264, 264, 264)
# Label: (164, 265, 266, 267, 268, 269, 270, 271, 164, 168)
#
#
# ^^^^^^^^^^ ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Candidate logs:  tensor([267,  11,  19,  20, 264, 164,  17, 265,   3,   5], device='cuda:0')
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Probabilities:  tf.Tensor([0.0367 0.0373 0.0459 0.0540 0.0759 0.0844 0.1227 0.1241 0.2005 0.2186], shape=(10,), dtype=float32)
#
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Encoder Attention Normalized [0.2207 0.2485 0.4489 1.0000 0.5919 0.6423 0.2497 0.0000 0.3808 0.2363]
#
#
#
#
# ~~~~~~~~~~ SEQUENCE BACKTRACE ~~~~~~~~~~
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 263 161    time <*> <*>"" level info msg ""[graphdriver] ...
# 264 95    time <*> <*>"" level warning msg ""Your kernel...
# 264 95    time <*> <*>"" level warning msg ""Your kernel...
# 264 95    time <*> <*>"" level warning msg ""Your kernel...
#
#
# ~~~~~~~~~~ LABEL BACKTRACE ~~~~~~~~~~
# 164 107    time <*> <*>"" level info msg ""Loading contai...
#
#
# ~~~~~~~~~~ PREDICTION BACKTRACE [Top 4] ~~~~~~~~~~
# 5 8    ens3 DHCP lease lost
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 265 151    <*> <*> Bridge firewalling registered
# 17 1    Could not set hostname Method call timed out
#
#
# ########## END OF INFO FOR LOG SEQUENCE 16 ##########
#
#
#
#
#
#
# ********** ********** ********** ********** **********
#      ********** INPUT SEQUENCE 8 - 17 **********
# ********** ********** ********** ********** **********
#
#
# ---------- ---------- ---------- ---------- ----------
# Input Sequence: (260, 260, 260, 260, 260, 263, 264, 264, 264, 164)
# Label: (265, 266, 267, 268, 269, 270, 271, 164, 168, 169)
#
#
# ^^^^^^^^^^ ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Candidate logs:  tensor([265,  16,  19,  17, 164, 117,   4, 401,  20,   3], device='cuda:0')
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Probabilities:  tf.Tensor([0.0608 0.0662 0.0686 0.0731 0.0733 0.0742 0.0785 0.1041 0.1242 0.2769], shape=(10,), dtype=float32)
#
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Encoder Attention Normalized [0.0000 0.0026 0.1032 0.0400 0.3386 0.0937 0.1602 0.0311 0.0489 1.0000]
#
#
#
#
# ~~~~~~~~~~ SEQUENCE BACKTRACE ~~~~~~~~~~
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 263 161    time <*> <*>"" level info msg ""[graphdriver] ...
# 264 95    time <*> <*>"" level warning msg ""Your kernel...
# 264 95    time <*> <*>"" level warning msg ""Your kernel...
# 264 95    time <*> <*>"" level warning msg ""Your kernel...
# 164 107    time <*> <*>"" level info msg ""Loading contai...
#
#
# ~~~~~~~~~~ LABEL BACKTRACE ~~~~~~~~~~
# 265 151    <*> <*> Bridge firewalling registered
#
#
# ~~~~~~~~~~ PREDICTION BACKTRACE [Top 4] ~~~~~~~~~~
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 20 14    pcp CMD <*> -C
# 401 17    <*> mDNS multicast group on interface <*> with...
# 4 19    root CMD cd / && run-parts --report <*>
#
#
# ########## END OF INFO FOR LOG SEQUENCE 17 ##########
#
#
#
#
#
#
# ********** ********** ********** ********** **********
#      ********** INPUT SEQUENCE 9 - 18 **********
# ********** ********** ********** ********** **********
#
#
# ---------- ---------- ---------- ---------- ----------
# Input Sequence: (260, 260, 260, 260, 263, 264, 264, 264, 164, 265)
# Label: (266, 267, 268, 269, 270, 271, 164, 168, 169, 170)
#
#
# ^^^^^^^^^^ ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Candidate logs:  tensor([ 15,  17,  41,  44,  51,  32,  28,  36, 169, 266], device='cuda:0')
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Probabilities:  tf.Tensor([0.0665 0.0667 0.0688 0.0726 0.0735 0.0763 0.0810 0.0827 0.1113 0.3006], shape=(10,), dtype=float32)
#
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Encoder Attention Normalized [0.3336 0.3536 0.3750 0.2796 0.3939 0.0000 0.2716 0.0000 1.0000 0.0884]
#
#
#
#
# ~~~~~~~~~~ SEQUENCE BACKTRACE ~~~~~~~~~~
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 263 161    time <*> <*>"" level info msg ""[graphdriver] ...
# 264 95    time <*> <*>"" level warning msg ""Your kernel...
# 264 95    time <*> <*>"" level warning msg ""Your kernel...
# 264 95    time <*> <*>"" level warning msg ""Your kernel...
# 164 107    time <*> <*>"" level info msg ""Loading contai...
# 265 151    <*> <*> Bridge firewalling registered
#
#
# ~~~~~~~~~~ LABEL BACKTRACE ~~~~~~~~~~
# 266 150    <*> <*> Initializing XFRM netlink socket
#
#
# ~~~~~~~~~~ PREDICTION BACKTRACE [Top 4] ~~~~~~~~~~
# 266 150    <*> <*> Initializing XFRM netlink socket
# 169 133    time <*> <*>"" level info msg ""Daemon has com...
# 36 41    pcp CMD /usr/lib/pcp/bin/pmlogger_daily
# 28 39    root CMD test -x /etc/cron.daily/popularity-co...
#
#
# ########## END OF INFO FOR LOG SEQUENCE 18 ##########
#
#
#
#
#
#
# ********** ********** ********** ********** **********
#      ********** INPUT SEQUENCE 10 - 19 **********
# ********** ********** ********** ********** **********
#
#
# ---------- ---------- ---------- ---------- ----------
# Input Sequence: (260, 260, 260, 263, 264, 264, 264, 164, 265, 266)
# Label: (267, 268, 269, 270, 271, 164, 168, 169, 170, 171)
# ../Source_Code/Transformer.py:495: RuntimeWarning: invalid value encountered in true_divide
#   normalized_weights =(att-np.min(att))/(np.max(att)-np.min(att))
# ../Source_Code/Transformer.py:495: RuntimeWarning: invalid value encountered in true_divide
#   normalized_weights =(att-np.min(att))/(np.max(att)-np.min(att))
# ../Source_Code/Transformer.py:495: RuntimeWarning: invalid value encountered in true_divide
#   normalized_weights =(att-np.min(att))/(np.max(att)-np.min(att))
# ../Source_Code/Transformer.py:495: RuntimeWarning: invalid value encountered in true_divide
#   normalized_weights =(att-np.min(att))/(np.max(att)-np.min(att))
# ../Source_Code/Transformer.py:495: RuntimeWarning: invalid value encountered in true_divide
#   normalized_weights =(att-np.min(att))/(np.max(att)-np.min(att))
# ^^^^^^^^^^ ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Candidate logs:  tensor([120, 265,   3, 271,  79, 268, 270, 269, 267,  15], device='cuda:0')
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Probabilities:  tf.Tensor([0.0544 0.0576 0.0591 0.0745 0.0834 0.1051 0.1167 0.1280 0.1295 0.1916], shape=(10,), dtype=float32)
#
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Encoder Attention Normalized [0.0000 0.0658 0.1079 0.0682 0.0572 0.1664 0.0445 1.0000 0.0575 0.0878]
#
#
#
#
# ~~~~~~~~~~ SEQUENCE BACKTRACE ~~~~~~~~~~
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 263 161    time <*> <*>"" level info msg ""[graphdriver] ...
# 264 95    time <*> <*>"" level warning msg ""Your kernel...
# 264 95    time <*> <*>"" level warning msg ""Your kernel...
# 264 95    time <*> <*>"" level warning msg ""Your kernel...
# 164 107    time <*> <*>"" level info msg ""Loading contai...
# 265 151    <*> <*> Bridge firewalling registered
# 266 150    <*> <*> Initializing XFRM netlink socket
#
#
# ~~~~~~~~~~ LABEL BACKTRACE ~~~~~~~~~~
# 267 145    <*> <*> Netfilter messages via NETLINK v0.<*>.
#
#
# ~~~~~~~~~~ PREDICTION BACKTRACE [Top 4] ~~~~~~~~~~
# 15 4    <*> Failed with result 'exit-code'.
# 267 145    <*> <*> Netfilter messages via NETLINK v0.<*>.
# 269 125    link_config autonegotiation is unset or enable...
# 270 148    WARNING Unknown index <*> seen reloading inter...
#
#
# ########## END OF INFO FOR LOG SEQUENCE 19 ##########
#
#
#
#
#
#
# ********** ********** ********** ********** **********
#      ********** INPUT SEQUENCE 11 - 20 **********
# ********** ********** ********** ********** **********
#
#
# ---------- ---------- ---------- ---------- ----------
# Input Sequence: (260, 260, 263, 264, 264, 264, 164, 265, 266, 267)
# Label: (268, 269, 270, 271, 164, 168, 169, 170, 171, 5)
#
#
# ^^^^^^^^^^ ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Candidate logs:  tensor([  6, 267, 169,  28,  47,  15,  79,   7,  18, 268], device='cuda:0')
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Probabilities:  tf.Tensor([0.0542 0.0543 0.0576 0.0583 0.0626 0.0631 0.0835 0.1216 0.1491 0.2957], shape=(10,), dtype=float32)
#
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Encoder Attention Normalized [0.0514 0.0883 0.0423 0.0000 0.1281 0.1570 1.0000 0.0468 0.1295 0.0729]
#
#
#
#
# ~~~~~~~~~~ SEQUENCE BACKTRACE ~~~~~~~~~~
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 263 161    time <*> <*>"" level info msg ""[graphdriver] ...
# 264 95    time <*> <*>"" level warning msg ""Your kernel...
# 264 95    time <*> <*>"" level warning msg ""Your kernel...
# 264 95    time <*> <*>"" level warning msg ""Your kernel...
# 164 107    time <*> <*>"" level info msg ""Loading contai...
# 265 151    <*> <*> Bridge firewalling registered
# 266 150    <*> <*> Initializing XFRM netlink socket
# 267 145    <*> <*> Netfilter messages via NETLINK v0.<*>.
#
#
# ~~~~~~~~~~ LABEL BACKTRACE ~~~~~~~~~~
# 268 144    <*> <*> ctnetlink v0.<*> registering with nfne...
#
#
# ~~~~~~~~~~ PREDICTION BACKTRACE [Top 4] ~~~~~~~~~~
# 268 144    <*> <*> ctnetlink v0.<*> registering with nfne...
# 18 11    Could not set hostname Failed to activate serv...
# 7 15    Network configuration changed trying to establ...
# 79 35    https //www.techrepublic.com/article/how-to-in...
#
#
# ########## END OF INFO FOR LOG SEQUENCE 20 ##########
#
#
#
#
#
#
# ********** ********** ********** ********** **********
#      ********** INPUT SEQUENCE 12 - 21 **********
# ********** ********** ********** ********** **********
#
#
# ---------- ---------- ---------- ---------- ----------
# Input Sequence: (260, 263, 264, 264, 264, 164, 265, 266, 267, 268)
# Label: (269, 270, 271, 164, 168, 169, 170, 171, 5, 6)
#
#
# ^^^^^^^^^^ ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Candidate logs:  tensor([268,  44,  17,   7,  19, 270, 269,   5,   3, 117], device='cuda:0')
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Probabilities:  tf.Tensor([0.0409 0.0689 0.0718 0.0854 0.0875 0.0965 0.0988 0.1212 0.1313 0.1977], shape=(10,), dtype=float32)
#
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Encoder Attention Normalized [0.0541 0.0562 0.0467 0.0653 0.0740 1.0000 0.0460 0.0000 0.0569 0.1678]
#
#
#
#
# ~~~~~~~~~~ SEQUENCE BACKTRACE ~~~~~~~~~~
# 260 73    time <*> <*>"" level info msg <*> <*> <*> modu...
# 263 161    time <*> <*>"" level info msg ""[graphdriver] ...
# 264 95    time <*> <*>"" level warning msg ""Your kernel...
# 264 95    time <*> <*>"" level warning msg ""Your kernel...
# 264 95    time <*> <*>"" level warning msg ""Your kernel...
# 164 107    time <*> <*>"" level info msg ""Loading contai...
# 265 151    <*> <*> Bridge firewalling registered
# 266 150    <*> <*> Initializing XFRM netlink socket
# 267 145    <*> <*> Netfilter messages via NETLINK v0.<*>.
# 268 144    <*> <*> ctnetlink v0.<*> registering with nfne...
#
#
# ~~~~~~~~~~ LABEL BACKTRACE ~~~~~~~~~~
# 269 125    link_config autonegotiation is unset or enable...
#
#
# ~~~~~~~~~~ PREDICTION BACKTRACE [Top 4] ~~~~~~~~~~
# 117 103    daemon.go <*> <*> waiting for running hooks
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 5 8    ens3 DHCP lease lost
# 269 125    link_config autonegotiation is unset or enable...
#
#
# ########## END OF INFO FOR LOG SEQUENCE 21 ##########
#
#
#
#
#
#
# ********** ********** ********** ********** **********
#      ********** INPUT SEQUENCE 13 - 22 **********
# ********** ********** ********** ********** **********
#
#
# ---------- ---------- ---------- ---------- ----------
# Input Sequence: (263, 264, 264, 264, 164, 265, 266, 267, 268, 269)
# Label: (270, 271, 164, 168, 169, 170, 171, 5, 6, 9)
#
#
# ^^^^^^^^^^ ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Candidate logs:  tensor([120,   7,   0, 271,  19,   3, 121, 117,   5, 270], device='cuda:0')
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Probabilities:  tf.Tensor([0.0630 0.0755 0.0762 0.0811 0.0930 0.1090 0.1181 0.1185 0.1263 0.1394], shape=(10,), dtype=float32)
#
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Encoder Attention Normalized [0.0608 0.0633 0.0000 0.0343 1.0000 0.2639 0.2677 0.2135 0.1559 0.0932]
#
#
#
#
# ~~~~~~~~~~ SEQUENCE BACKTRACE ~~~~~~~~~~
# 263 161    time <*> <*>"" level info msg ""[graphdriver] ...
# 264 95    time <*> <*>"" level warning msg ""Your kernel...
# 264 95    time <*> <*>"" level warning msg ""Your kernel...
# 264 95    time <*> <*>"" level warning msg ""Your kernel...
# 164 107    time <*> <*>"" level info msg ""Loading contai...
# 265 151    <*> <*> Bridge firewalling registered
# 266 150    <*> <*> Initializing XFRM netlink socket
# 267 145    <*> <*> Netfilter messages via NETLINK v0.<*>.
# 268 144    <*> <*> ctnetlink v0.<*> registering with nfne...
# 269 125    link_config autonegotiation is unset or enable...
#
#
# ~~~~~~~~~~ LABEL BACKTRACE ~~~~~~~~~~
# 270 148    WARNING Unknown index <*> seen reloading inter...
#
#
# ~~~~~~~~~~ PREDICTION BACKTRACE [Top 4] ~~~~~~~~~~
# 270 148    WARNING Unknown index <*> seen reloading inter...
# 5 8    ens3 DHCP lease lost
# 117 103    daemon.go <*> <*> waiting for running hooks
# 121 30    [W <*>.<*> LabApp] <*>
#
#
# ########## END OF INFO FOR LOG SEQUENCE 22 ##########
#
#
#
#
#
#
# ********** ********** ********** ********** **********
#      ********** INPUT SEQUENCE 14 - 23 **********
# ********** ********** ********** ********** **********
#
#
# ---------- ---------- ---------- ---------- ----------
# Input Sequence: (264, 264, 264, 164, 265, 266, 267, 268, 269, 270)
# Label: (271, 164, 168, 169, 170, 171, 5, 6, 9, 8)
#
#
# ^^^^^^^^^^ ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Candidate logs:  tensor([171,   4, 169,  26,   7,  44, 117,  19,  17,   5], device='cuda:0')
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Probabilities:  tf.Tensor([0.0414 0.0440 0.0508 0.0598 0.0729 0.0775 0.1138 0.1227 0.1437 0.2734], shape=(10,), dtype=float32)
#
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Encoder Attention Normalized [0.1142 0.2062 0.0455 1.0000 0.0000 0.4421 0.3304 0.1100 0.2783 0.3784]
#
#
# |||||||||| |||||||||| |||||||||| |||||||||| ||||||||||
#         >>>>>>>>>> ANOMALY DETECTED <<<<<<<<<<
# |||||||||| |||||||||| |||||||||| |||||||||| ||||||||||
#
#
#
#
# ~~~~~~~~~~ SEQUENCE BACKTRACE ~~~~~~~~~~
# 264 95    time <*> <*>"" level warning msg ""Your kernel...
# 264 95    time <*> <*>"" level warning msg ""Your kernel...
# 264 95    time <*> <*>"" level warning msg ""Your kernel...
# 164 107    time <*> <*>"" level info msg ""Loading contai...
# 265 151    <*> <*> Bridge firewalling registered
# 266 150    <*> <*> Initializing XFRM netlink socket
# 267 145    <*> <*> Netfilter messages via NETLINK v0.<*>.
# 268 144    <*> <*> ctnetlink v0.<*> registering with nfne...
# 269 125    link_config autonegotiation is unset or enable...
# 270 148    WARNING Unknown index <*> seen reloading inter...
#
#
# ~~~~~~~~~~ LABEL BACKTRACE ~~~~~~~~~~
# 271 143    <*> Link UP
#
#
# ~~~~~~~~~~ PREDICTION BACKTRACE [Top 4] ~~~~~~~~~~
# 5 8    ens3 DHCP lease lost
# 17 1    Could not set hostname Method call timed out
# 19 16    Synchronized to time server <*> <*> <*> .
# 117 103    daemon.go <*> <*> waiting for running hooks
#
#
# ########## END OF INFO FOR LOG SEQUENCE 23 ##########
#
#
#
#
#
#
# ********** ********** ********** ********** **********
#      ********** INPUT SEQUENCE 15 - 24 **********
# ********** ********** ********** ********** **********
#
#
# ---------- ---------- ---------- ---------- ----------
# Input Sequence: (264, 264, 164, 265, 266, 267, 268, 269, 270, 271)
# Label: (164, 168, 169, 170, 171, 5, 6, 9, 8, 10)
# ../Source_Code/Transformer.py:495: RuntimeWarning: invalid value encountered in true_divide
#   normalized_weights =(att-np.min(att))/(np.max(att)-np.min(att))
# ../Source_Code/Transformer.py:495: RuntimeWarning: invalid value encountered in true_divide
#   normalized_weights =(att-np.min(att))/(np.max(att)-np.min(att))
# ../Source_Code/Transformer.py:495: RuntimeWarning: invalid value encountered in true_divide
#   normalized_weights =(att-np.min(att))/(np.max(att)-np.min(att))
# ../Source_Code/Transformer.py:495: RuntimeWarning: invalid value encountered in true_divide
#   normalized_weights =(att-np.min(att))/(np.max(att)-np.min(att))
# /home/ubuntu/.local/lib/python3.6/site-packages/ipykernel_launcher.py:58: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
# ../Source_Code/Transformer.py:495: RuntimeWarning: invalid value encountered in true_divide
#   normalized_weights =(att-np.min(att))/(np.max(att)-np.min(att))
# ^^^^^^^^^^ ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Candidate logs:  tensor([270, 271,  19, 169,  16,   5,  18, 164,   7, 117], device='cuda:0')
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Probabilities:  tf.Tensor([0.0465 0.0508 0.0635 0.0803 0.0815 0.0949 0.1246 0.1434 0.1478 0.1667], shape=(10,), dtype=float32)
#
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Encoder Attention Normalized [0.0911 0.1067 1.0000 0.0566 0.9207 0.4897 0.2085 0.6982 0.3156 0.0000]
#
#
#
#
# ~~~~~~~~~~ SEQUENCE BACKTRACE ~~~~~~~~~~
# 264 95    time <*> <*>"" level warning msg ""Your kernel...
# 264 95    time <*> <*>"" level warning msg ""Your kernel...
# 164 107    time <*> <*>"" level info msg ""Loading contai...
# 265 151    <*> <*> Bridge firewalling registered
# 266 150    <*> <*> Initializing XFRM netlink socket
# 267 145    <*> <*> Netfilter messages via NETLINK v0.<*>.
# 268 144    <*> <*> ctnetlink v0.<*> registering with nfne...
# 269 125    link_config autonegotiation is unset or enable...
# 270 148    WARNING Unknown index <*> seen reloading inter...
# 271 143    <*> Link UP
#
#
# ~~~~~~~~~~ LABEL BACKTRACE ~~~~~~~~~~
# 164 107    time <*> <*>"" level info msg ""Loading contai...
#
#
# ~~~~~~~~~~ PREDICTION BACKTRACE [Top 4] ~~~~~~~~~~
# 117 103    daemon.go <*> <*> waiting for running hooks
# 7 15    Network configuration changed trying to establ...
# 164 107    time <*> <*>"" level info msg ""Loading contai...
# 18 11    Could not set hostname Failed to activate serv...
#
#
# ########## END OF INFO FOR LOG SEQUENCE 24 ##########
#
#
#
#
#
#
# ********** ********** ********** ********** **********
#      ********** INPUT SEQUENCE 16 - 25 **********
# ********** ********** ********** ********** **********
#
#
# ---------- ---------- ---------- ---------- ----------
# Input Sequence: (264, 164, 265, 266, 267, 268, 269, 270, 271, 164)
# Label: (168, 169, 170, 171, 5, 6, 9, 8, 10, 11)
#
#
# ^^^^^^^^^^ ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Candidate logs:  tensor([ 11, 169,   2, 117, 164,   5,  67,  19, 168,   3], device='cuda:0')
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Probabilities:  tf.Tensor([0.0434 0.0437 0.0439 0.0499 0.0533 0.0638 0.0655 0.1006 0.1027 0.4332], shape=(10,), dtype=float32)
#
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Encoder Attention Normalized [0.0479 0.4164 0.0645 0.3941 0.0000 0.2932 0.2304 0.3086 0.2420 1.0000]
#
#
#
#
# ~~~~~~~~~~ SEQUENCE BACKTRACE ~~~~~~~~~~
# 264 95    time <*> <*>"" level warning msg ""Your kernel...
# 164 107    time <*> <*>"" level info msg ""Loading contai...
# 265 151    <*> <*> Bridge firewalling registered
# 266 150    <*> <*> Initializing XFRM netlink socket
# 267 145    <*> <*> Netfilter messages via NETLINK v0.<*>.
# 268 144    <*> <*> ctnetlink v0.<*> registering with nfne...
# 269 125    link_config autonegotiation is unset or enable...
# 270 148    WARNING Unknown index <*> seen reloading inter...
# 271 143    <*> Link UP
# 164 107    time <*> <*>"" level info msg ""Loading contai...
#
#
# ~~~~~~~~~~ LABEL BACKTRACE ~~~~~~~~~~
# 168 131    time <*> <*>"" level info msg ""Docker daemon"...
#
#
# ~~~~~~~~~~ PREDICTION BACKTRACE [Top 4] ~~~~~~~~~~
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 168 131    time <*> <*>"" level info msg ""Docker daemon"...
# 19 16    Synchronized to time server <*> <*> <*> .
# 67 45    File <*> line <*> in <*>
#
#
# ########## END OF INFO FOR LOG SEQUENCE 25 ##########
#
#
#
#
#
#
# ********** ********** ********** ********** **********
#      ********** INPUT SEQUENCE 17 - 26 **********
# ********** ********** ********** ********** **********
#
#
# ---------- ---------- ---------- ---------- ----------
# Input Sequence: (164, 265, 266, 267, 268, 269, 270, 271, 164, 168)
# Label: (169, 170, 171, 5, 6, 9, 8, 10, 11, 9)
#
#
# ^^^^^^^^^^ ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Candidate logs:  tensor([ 19, 117, 170,   6,  67,  66, 171,  18,   7, 169], device='cuda:0')
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Probabilities:  tf.Tensor([0.0402 0.0415 0.0476 0.0607 0.0686 0.0752 0.0838 0.1323 0.2030 0.2472], shape=(10,), dtype=float32)
#
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Encoder Attention Normalized [0.3569 0.0000 0.4130 0.3967 0.3395 0.1607 0.7211 1.0000 0.7610 0.8002]
#
#
#
#
# ~~~~~~~~~~ SEQUENCE BACKTRACE ~~~~~~~~~~
# 164 107    time <*> <*>"" level info msg ""Loading contai...
# 265 151    <*> <*> Bridge firewalling registered
# 266 150    <*> <*> Initializing XFRM netlink socket
# 267 145    <*> <*> Netfilter messages via NETLINK v0.<*>.
# 268 144    <*> <*> ctnetlink v0.<*> registering with nfne...
# 269 125    link_config autonegotiation is unset or enable...
# 270 148    WARNING Unknown index <*> seen reloading inter...
# 271 143    <*> Link UP
# 164 107    time <*> <*>"" level info msg ""Loading contai...
# 168 131    time <*> <*>"" level info msg ""Docker daemon"...
#
#
# ~~~~~~~~~~ LABEL BACKTRACE ~~~~~~~~~~
# 169 133    time <*> <*>"" level info msg ""Daemon has com...
#
#
# ~~~~~~~~~~ PREDICTION BACKTRACE [Top 4] ~~~~~~~~~~
# 169 133    time <*> <*>"" level info msg ""Daemon has com...
# 7 15    Network configuration changed trying to establ...
# 18 11    Could not set hostname Failed to activate serv...
# 171 123    time <*> <*>"" level info msg ""API listen on ...
#
#
# ########## END OF INFO FOR LOG SEQUENCE 26 ##########
#
#
#
#
#
#
# ********** ********** ********** ********** **********
#      ********** INPUT SEQUENCE 18 - 27 **********
# ********** ********** ********** ********** **********
#
#
# ---------- ---------- ---------- ---------- ----------
# Input Sequence: (265, 266, 267, 268, 269, 270, 271, 164, 168, 169)
# Label: (170, 171, 5, 6, 9, 8, 10, 11, 9, 420)
#
#
# ^^^^^^^^^^ ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Candidate logs:  tensor([117, 170,  26, 169,  44, 171,   3,   5,  17,  19], device='cuda:0')
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Probabilities:  tf.Tensor([0.0315 0.0403 0.0511 0.0538 0.0572 0.0710 0.0994 0.1675 0.1733 0.2550], shape=(10,), dtype=float32)
#
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Encoder Attention Normalized [0.0000 0.0917 0.0261 0.0405 0.2184 0.2450 0.1685 1.0000 0.1186 0.2185]
#
#
#
#
# ~~~~~~~~~~ SEQUENCE BACKTRACE ~~~~~~~~~~
# 265 151    <*> <*> Bridge firewalling registered
# 266 150    <*> <*> Initializing XFRM netlink socket
# 267 145    <*> <*> Netfilter messages via NETLINK v0.<*>.
# 268 144    <*> <*> ctnetlink v0.<*> registering with nfne...
# 269 125    link_config autonegotiation is unset or enable...
# 270 148    WARNING Unknown index <*> seen reloading inter...
# 271 143    <*> Link UP
# 164 107    time <*> <*>"" level info msg ""Loading contai...
# 168 131    time <*> <*>"" level info msg ""Docker daemon"...
# 169 133    time <*> <*>"" level info msg ""Daemon has com...
#
#
# ~~~~~~~~~~ LABEL BACKTRACE ~~~~~~~~~~
# 170 118    Started Docker Application Container Engine.
#
#
# ~~~~~~~~~~ PREDICTION BACKTRACE [Top 4] ~~~~~~~~~~
# 19 16    Synchronized to time server <*> <*> <*> .
# 17 1    Could not set hostname Method call timed out
# 5 8    ens3 DHCP lease lost
# 3 25    Server returned error NXDOMAIN mitigating pote...
#
#
# ########## END OF INFO FOR LOG SEQUENCE 27 ##########
#
#
#
#
#
#
# ********** ********** ********** ********** **********
#      ********** INPUT SEQUENCE 19 - 28 **********
# ********** ********** ********** ********** **********
#
#
# ---------- ---------- ---------- ---------- ----------
# Input Sequence: (266, 267, 268, 269, 270, 271, 164, 168, 169, 170)
# Label: (171, 5, 6, 9, 8, 10, 11, 9, 420, 421)
#
#
# ^^^^^^^^^^ ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Candidate logs:  tensor([ 11,  44,   7,   3, 171,   5, 172,  67, 117,   2], device='cuda:0')
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Probabilities:  tf.Tensor([0.0621 0.0639 0.0650 0.0756 0.1102 0.1106 0.1151 0.1192 0.1268 0.1514], shape=(10,), dtype=float32)
#
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Encoder Attention Normalized [0.2093 0.3240 0.0880 0.2886 0.3587 0.4472 1.0000 0.4285 0.2259 0.0000]
#
#
#
#
# ~~~~~~~~~~ SEQUENCE BACKTRACE ~~~~~~~~~~
# 266 150    <*> <*> Initializing XFRM netlink socket
# 267 145    <*> <*> Netfilter messages via NETLINK v0.<*>.
# 268 144    <*> <*> ctnetlink v0.<*> registering with nfne...
# 269 125    link_config autonegotiation is unset or enable...
# 270 148    WARNING Unknown index <*> seen reloading inter...
# 271 143    <*> Link UP
# 164 107    time <*> <*>"" level info msg ""Loading contai...
# 168 131    time <*> <*>"" level info msg ""Docker daemon"...
# 169 133    time <*> <*>"" level info msg ""Daemon has com...
# 170 118    Started Docker Application Container Engine.
#
#
# ~~~~~~~~~~ LABEL BACKTRACE ~~~~~~~~~~
# 171 123    time <*> <*>"" level info msg ""API listen on ...
#
#
# ~~~~~~~~~~ PREDICTION BACKTRACE [Top 4] ~~~~~~~~~~
# 2 120    Startup finished in <*> kernel + <*> userspace...
# 117 103    daemon.go <*> <*> waiting for running hooks
# 67 45    File <*> line <*> in <*>
# 172 138    [W <*>.<*> LabApp] JupyterLab server extension...
#
#
# ########## END OF INFO FOR LOG SEQUENCE 28 ##########
#
#
#
#
#
#
# ********** ********** ********** ********** **********
#      ********** INPUT SEQUENCE 20 - 29 **********
# ********** ********** ********** ********** **********
#
#
# ---------- ---------- ---------- ---------- ----------
# Input Sequence: (267, 268, 269, 270, 271, 164, 168, 169, 170, 171)
# Label: (5, 6, 9, 8, 10, 11, 9, 420, 421, 423)
# ../Source_Code/Transformer.py:495: RuntimeWarning: invalid value encountered in true_divide
#   normalized_weights =(att-np.min(att))/(np.max(att)-np.min(att))
# ../Source_Code/Transformer.py:495: RuntimeWarning: invalid value encountered in true_divide
#   normalized_weights =(att-np.min(att))/(np.max(att)-np.min(att))
# ../Source_Code/Transformer.py:495: RuntimeWarning: invalid value encountered in true_divide
#   normalized_weights =(att-np.min(att))/(np.max(att)-np.min(att))
# ../Source_Code/Transformer.py:495: RuntimeWarning: invalid value encountered in true_divide
#   normalized_weights =(att-np.min(att))/(np.max(att)-np.min(att))
# ../Source_Code/Transformer.py:495: RuntimeWarning: invalid value encountered in true_divide
#   normalized_weights =(att-np.min(att))/(np.max(att)-np.min(att))
# /home/ubuntu/.local/lib/python3.6/site-packages/ipykernel_launcher.py:58: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
# ^^^^^^^^^^ ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Candidate logs:  tensor([164, 191, 170, 175,   3, 172,  22, 117, 169,   2], device='cuda:0')
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Probabilities:  tf.Tensor([0.0514 0.0551 0.0594 0.0842 0.0862 0.0976 0.0979 0.1448 0.1571 0.1664], shape=(10,), dtype=float32)
#
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Encoder Attention Normalized [0.0000 0.0601 0.0727 0.2972 0.1082 1.0000 0.2091 0.1348 0.0000 0.1330]
#
#
# |||||||||| |||||||||| |||||||||| |||||||||| ||||||||||
#         >>>>>>>>>> ANOMALY DETECTED <<<<<<<<<<
# |||||||||| |||||||||| |||||||||| |||||||||| ||||||||||
#
#
#
#
# ~~~~~~~~~~ SEQUENCE BACKTRACE ~~~~~~~~~~
# 267 145    <*> <*> Netfilter messages via NETLINK v0.<*>.
# 268 144    <*> <*> ctnetlink v0.<*> registering with nfne...
# 269 125    link_config autonegotiation is unset or enable...
# 270 148    WARNING Unknown index <*> seen reloading inter...
# 271 143    <*> Link UP
# 164 107    time <*> <*>"" level info msg ""Loading contai...
# 168 131    time <*> <*>"" level info msg ""Docker daemon"...
# 169 133    time <*> <*>"" level info msg ""Daemon has com...
# 170 118    Started Docker Application Container Engine.
# 171 123    time <*> <*>"" level info msg ""API listen on ...
#
#
# ~~~~~~~~~~ LABEL BACKTRACE ~~~~~~~~~~
# 5 8    ens3 DHCP lease lost
#
#
# ~~~~~~~~~~ PREDICTION BACKTRACE [Top 4] ~~~~~~~~~~
# 2 120    Startup finished in <*> kernel + <*> userspace...
# 169 133    time <*> <*>"" level info msg ""Daemon has com...
# 117 103    daemon.go <*> <*> waiting for running hooks
# 22 38    Started Cleanup of Temporary Directories.
#
#
# ########## END OF INFO FOR LOG SEQUENCE 29 ##########
#
#
#
#
#
#
# ********** ********** ********** ********** **********
#      ********** INPUT SEQUENCE 21 - 30 **********
# ********** ********** ********** ********** **********
#
#
# ---------- ---------- ---------- ---------- ----------
# Input Sequence: (268, 269, 270, 271, 164, 168, 169, 170, 171, 5)
# Label: (6, 9, 8, 10, 11, 9, 420, 421, 423, 423)
#
#
# ^^^^^^^^^^ ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Candidate logs:  tensor([443, 218, 175, 204,  18,   9, 404,   8,   7,   6], device='cuda:0')
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Probabilities:  tf.Tensor([0.0004 0.0004 0.0004 0.0004 0.0004 0.0010 0.0041 0.0080 0.0195 0.9654], shape=(10,), dtype=float32)
#
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Encoder Attention Normalized [0.1033 0.1541 0.3469 0.1229 1.0000 0.3562 0.2065 0.0000 0.1646 0.3072]
#
#
#
#
# ~~~~~~~~~~ SEQUENCE BACKTRACE ~~~~~~~~~~
# 268 144    <*> <*> ctnetlink v0.<*> registering with nfne...
# 269 125    link_config autonegotiation is unset or enable...
# 270 148    WARNING Unknown index <*> seen reloading inter...
# 271 143    <*> Link UP
# 164 107    time <*> <*>"" level info msg ""Loading contai...
# 168 131    time <*> <*>"" level info msg ""Docker daemon"...
# 169 133    time <*> <*>"" level info msg ""Daemon has com...
# 170 118    Started Docker Application Container Engine.
# 171 123    time <*> <*>"" level info msg ""API listen on ...
# 5 8    ens3 DHCP lease lost
#
#
# ~~~~~~~~~~ LABEL BACKTRACE ~~~~~~~~~~
# 6 6    [system] Activating via systemd service name '...
#
#
# ~~~~~~~~~~ PREDICTION BACKTRACE [Top 4] ~~~~~~~~~~
# 6 6    [system] Activating via systemd service name '...
# 7 15    Network configuration changed trying to establ...
# 8 2    Starting <*> Service...
# 404 18    <*> <*> address record for <*> on <*>
#
#
# ########## END OF INFO FOR LOG SEQUENCE 30 ##########
#
#
#
#
#
#
# ********** ********** ********** ********** **********
#      ********** INPUT SEQUENCE 22 - 31 **********
# ********** ********** ********** ********** **********
#
#
# ---------- ---------- ---------- ---------- ----------
# Input Sequence: (269, 270, 271, 164, 168, 169, 170, 171, 5, 6)
# Label: (9, 8, 10, 11, 9, 420, 421, 423, 423, 423)
#
#
# ^^^^^^^^^^ ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Candidate logs:  tensor([137, 321,  54, 411, 261, 404,  10,   9,   7,   8], device='cuda:0')
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Probabilities:  tf.Tensor([0.0005 0.0005 0.0005 0.0005 0.0005 0.0015 0.0036 0.0198 0.1430 0.8297], shape=(10,), dtype=float32)
#
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Encoder Attention Normalized [0.0941 0.0000 0.1666 0.7523 0.1759 0.3497 0.0774 0.2351 1.0000 0.2243]
#
#
#
#
# ~~~~~~~~~~ SEQUENCE BACKTRACE ~~~~~~~~~~
# 269 125    link_config autonegotiation is unset or enable...
# 270 148    WARNING Unknown index <*> seen reloading inter...
# 271 143    <*> Link UP
# 164 107    time <*> <*>"" level info msg ""Loading contai...
# 168 131    time <*> <*>"" level info msg ""Docker daemon"...
# 169 133    time <*> <*>"" level info msg ""Daemon has com...
# 170 118    Started Docker Application Container Engine.
# 171 123    time <*> <*>"" level info msg ""API listen on ...
# 5 8    ens3 DHCP lease lost
# 6 6    [system] Activating via systemd service name '...
#
#
# ~~~~~~~~~~ LABEL BACKTRACE ~~~~~~~~~~
# 9 12    Started ntp-systemd-netif.service.
#
#
# ~~~~~~~~~~ PREDICTION BACKTRACE [Top 4] ~~~~~~~~~~
# 8 2    Starting <*> Service...
# 7 15    Network configuration changed trying to establ...
# 9 12    Started ntp-systemd-netif.service.
# 10 7    ens3 DHCPv4 address <*>/<*> via <*>
#
#
# ########## END OF INFO FOR LOG SEQUENCE 31 ##########
#
#
#
#
#
#
# ********** ********** ********** ********** **********
#      ********** INPUT SEQUENCE 23 - 32 **********
# ********** ********** ********** ********** **********
#
#
# ---------- ---------- ---------- ---------- ----------
# Input Sequence: (270, 271, 164, 168, 169, 170, 171, 5, 6, 9)
# Label: (8, 10, 11, 9, 420, 421, 423, 423, 423, 423)
#
#
# ^^^^^^^^^^ ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Candidate logs:  tensor([295, 401,  74, 411, 404,  12,   6,   7,  10,   8], device='cuda:0')
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Probabilities:  tf.Tensor([0.0005 0.0005 0.0005 0.0009 0.0010 0.0011 0.0039 0.0071 0.0384 0.9462], shape=(10,), dtype=float32)
#
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Encoder Attention Normalized [0.0000 0.2901 1.0000 0.4269 0.2433 0.1680 0.5275 0.0000 0.3845 0.1695]
#
#
#
#
# ~~~~~~~~~~ SEQUENCE BACKTRACE ~~~~~~~~~~
# 270 148    WARNING Unknown index <*> seen reloading inter...
# 271 143    <*> Link UP
# 164 107    time <*> <*>"" level info msg ""Loading contai...
# 168 131    time <*> <*>"" level info msg ""Docker daemon"...
# 169 133    time <*> <*>"" level info msg ""Daemon has com...
# 170 118    Started Docker Application Container Engine.
# 171 123    time <*> <*>"" level info msg ""API listen on ...
# 5 8    ens3 DHCP lease lost
# 6 6    [system] Activating via systemd service name '...
# 9 12    Started ntp-systemd-netif.service.
#
#
# ~~~~~~~~~~ LABEL BACKTRACE ~~~~~~~~~~
# 8 2    Starting <*> Service...
#
#
# ~~~~~~~~~~ PREDICTION BACKTRACE [Top 4] ~~~~~~~~~~
# 8 2    Starting <*> Service...
# 10 7    ens3 DHCPv4 address <*>/<*> via <*>
# 7 15    Network configuration changed trying to establ...
# 6 6    [system] Activating via systemd service name '...
#
#
# ########## END OF INFO FOR LOG SEQUENCE 32 ##########
#
#
#
#
#
#
# ********** ********** ********** ********** **********
#      ********** INPUT SEQUENCE 24 - 33 **********
# ********** ********** ********** ********** **********
#
#
# ---------- ---------- ---------- ---------- ----------
# Input Sequence: (271, 164, 168, 169, 170, 171, 5, 6, 9, 8)
# Label: (10, 11, 9, 420, 421, 423, 423, 423, 423, 423)
#
#
# ^^^^^^^^^^ ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Candidate logs:  tensor([ 31, 171, 411,   5,  17,  14,   9,   7,  12,  10], device='cuda:0')
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Probabilities:  tf.Tensor([0.0003 0.0003 0.0003 0.0003 0.0003 0.0004 0.0005 0.0006 0.0070 0.9899], shape=(10,), dtype=float32)
#
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Encoder Attention Normalized [0.0980 0.3155 0.0627 0.0726 0.0000 0.2351 1.0000 0.0000 0.0000 0.0788]
#
#
#
#
# ~~~~~~~~~~ SEQUENCE BACKTRACE ~~~~~~~~~~
# 271 143    <*> Link UP
# 164 107    time <*> <*>"" level info msg ""Loading contai...
# 168 131    time <*> <*>"" level info msg ""Docker daemon"...
# 169 133    time <*> <*>"" level info msg ""Daemon has com...
# 170 118    Started Docker Application Container Engine.
# 171 123    time <*> <*>"" level info msg ""API listen on ...
# 5 8    ens3 DHCP lease lost
# 6 6    [system] Activating via systemd service name '...
# 9 12    Started ntp-systemd-netif.service.
# 8 2    Starting <*> Service...
#
#
# ~~~~~~~~~~ LABEL BACKTRACE ~~~~~~~~~~
# 10 7    ens3 DHCPv4 address <*>/<*> via <*>
#
#
# ...
# 5 8    ens3 DHCP lease lost
# 26 13    Low random number entropy available <*>
#
#
# ########## END OF INFO FOR LOG SEQUENCE 314 ##########
#
#
#
#
#
#
# ********** ********** ********** ********** **********
#      ********** INPUT SEQUENCE 306 - 315 **********
# ********** ********** ********** ********** **********
#
#
# ---------- ---------- ---------- ---------- ----------
# Input Sequence: (444, 3, 444, 3, 3, 3, 3, 3, 3, 3)
# Label: (3, 3, 3, 3, 3, 3, 3, 3)
#
#
# ^^^^^^^^^^ ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Candidate logs:  tensor([49, 19, 20,  4, 38, 26, 34, 17,  5,  3], device='cuda:0')
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Probabilities:  tf.Tensor([0.0003 0.0006 0.0007 0.0012 0.0012 0.0023 0.0037 0.0058 0.0076 0.9766], shape=(10,), dtype=float32)
#
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Encoder Attention Normalized [0.2893 0.1187 0.4825 1.0000 0.0000 0.4950 0.0000 0.4101 0.5258 0.3622]
#
#
#
#
# ~~~~~~~~~~ SEQUENCE BACKTRACE ~~~~~~~~~~
# 444 176    [ <*>.<*>] nf_conntrack nf_conntrack table ful...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 444 176    [ <*>.<*>] nf_conntrack nf_conntrack table ful...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
#
#
# ~~~~~~~~~~ LABEL BACKTRACE ~~~~~~~~~~
# 3 25    Server returned error NXDOMAIN mitigating pote...
#
#
# ~~~~~~~~~~ PREDICTION BACKTRACE [Top 4] ~~~~~~~~~~
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 5 8    ens3 DHCP lease lost
# 17 1    Could not set hostname Method call timed out
# 34 27    Started Daily apt <*> activities.
#
#
# ########## END OF INFO FOR LOG SEQUENCE 315 ##########
#
#
#
#
#
#
# ********** ********** ********** ********** **********
#      ********** INPUT SEQUENCE 307 - 316 **********
# ********** ********** ********** ********** **********
#
#
# ---------- ---------- ---------- ---------- ----------
# Input Sequence: (3, 444, 3, 3, 3, 3, 3, 3, 3, 3)
# Label: (3, 3, 3, 3, 3, 3, 3)
#
#
# ^^^^^^^^^^ ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Candidate logs:  tensor([20, 19, 11, 34,  4, 26, 38,  5, 17,  3], device='cuda:0')
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Probabilities:  tf.Tensor([0.0005 0.0008 0.0009 0.0010 0.0010 0.0034 0.0042 0.0214 0.0215 0.9454], shape=(10,), dtype=float32)
#
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Encoder Attention Normalized [0.0000 0.0299 0.0768 0.0982 0.2486 0.6271 0.7702 0.1697 1.0000 0.2057]
#
#
#
#
# ~~~~~~~~~~ SEQUENCE BACKTRACE ~~~~~~~~~~
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 444 176    [ <*>.<*>] nf_conntrack nf_conntrack table ful...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
#
#
# ~~~~~~~~~~ LABEL BACKTRACE ~~~~~~~~~~
# 3 25    Server returned error NXDOMAIN mitigating pote...
#
#
# ~~~~~~~~~~ PREDICTION BACKTRACE [Top 4] ~~~~~~~~~~
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 17 1    Could not set hostname Method call timed out
# 5 8    ens3 DHCP lease lost
# 38 128    [origin software ""rsyslogd"" swVersion ""<*>....
#
#
# ########## END OF INFO FOR LOG SEQUENCE 316 ##########
#
#
#
#
#
#
# ********** ********** ********** ********** **********
#      ********** INPUT SEQUENCE 308 - 317 **********
# ********** ********** ********** ********** **********
#
#
# ---------- ---------- ---------- ---------- ----------
# Input Sequence: (444, 3, 3, 3, 3, 3, 3, 3, 3, 3)
# Label: (3, 3, 3, 3, 3, 3)
#
#
# ^^^^^^^^^^ ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Candidate logs:  tensor([ 8, 49, 58, 38, 26, 11, 34, 17,  5,  3], device='cuda:0')
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Probabilities:  tf.Tensor([0.0004 0.0005 0.0006 0.0009 0.0011 0.0017 0.0047 0.0066 0.0071 0.9762], shape=(10,), dtype=float32)
#
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Encoder Attention Normalized [0.3608 0.3282 0.0000 0.5567 0.9669 0.7576 0.7415 1.0000 0.5283 0.4224]
#
#
#
#
# ~~~~~~~~~~ SEQUENCE BACKTRACE ~~~~~~~~~~
# 444 176    [ <*>.<*>] nf_conntrack nf_conntrack table ful...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
#
#
# ~~~~~~~~~~ LABEL BACKTRACE ~~~~~~~~~~
# 3 25    Server returned error NXDOMAIN mitigating pote...
#
#
# ~~~~~~~~~~ PREDICTION BACKTRACE [Top 4] ~~~~~~~~~~
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 5 8    ens3 DHCP lease lost
# 17 1    Could not set hostname Method call timed out
# 34 27    Started Daily apt <*> activities.
#
#
# ########## END OF INFO FOR LOG SEQUENCE 317 ##########
#
#
#
#
#
#
# ********** ********** ********** ********** **********
#      ********** INPUT SEQUENCE 309 - 318 **********
# ********** ********** ********** ********** **********
#
#
# ---------- ---------- ---------- ---------- ----------
# Input Sequence: (3, 3, 3, 3, 3, 3, 3, 3, 3, 3)
# Label: (3, 3, 3, 3, 3)
#
#
# ^^^^^^^^^^ ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Candidate logs:  tensor([ 4, 20, 19, 11, 38, 34, 26,  5, 17,  3], device='cuda:0')
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Probabilities:  tf.Tensor([0.0004 0.0005 0.0008 0.0012 0.0014 0.0023 0.0030 0.0203 0.0225 0.9476], shape=(10,), dtype=float32)
#
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Encoder Attention Normalized [0.2778 0.0000 0.4645 0.7482 0.5556 1.0000 0.9632 0.7768 0.8684 0.6769]
#
#
#
#
# ~~~~~~~~~~ SEQUENCE BACKTRACE ~~~~~~~~~~
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
#
#
# ~~~~~~~~~~ LABEL BACKTRACE ~~~~~~~~~~
# 3 25    Server returned error NXDOMAIN mitigating pote...
#
#
# ~~~~~~~~~~ PREDICTION BACKTRACE [Top 4] ~~~~~~~~~~
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 17 1    Could not set hostname Method call timed out
# 5 8    ens3 DHCP lease lost
# 26 13    Low random number entropy available <*>
#
#
# ########## END OF INFO FOR LOG SEQUENCE 318 ##########
#
#
#
#
#
#
# ********** ********** ********** ********** **********
#      ********** INPUT SEQUENCE 310 - 319 **********
# ********** ********** ********** ********** **********
#
#
# ---------- ---------- ---------- ---------- ----------
# Input Sequence: (3, 3, 3, 3, 3, 3, 3, 3, 3, 3)
# Label: (3, 3, 3, 3)
# ../Source_Code/Transformer.py:495: RuntimeWarning: invalid value encountered in true_divide
#   normalized_weights =(att-np.min(att))/(np.max(att)-np.min(att))
# ../Source_Code/Transformer.py:495: RuntimeWarning: invalid value encountered in true_divide
#   normalized_weights =(att-np.min(att))/(np.max(att)-np.min(att))
# ../Source_Code/Transformer.py:495: RuntimeWarning: invalid value encountered in true_divide
#   normalized_weights =(att-np.min(att))/(np.max(att)-np.min(att))
# ../Source_Code/Transformer.py:495: RuntimeWarning: invalid value encountered in true_divide
#   normalized_weights =(att-np.min(att))/(np.max(att)-np.min(att))
# ../Source_Code/Transformer.py:495: RuntimeWarning: invalid value encountered in true_divide
#   normalized_weights =(att-np.min(att))/(np.max(att)-np.min(att))
# ^^^^^^^^^^ ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Candidate logs:  tensor([34, 20, 19, 11,  4, 38, 26,  5, 17,  3], device='cuda:0')
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Probabilities:  tf.Tensor([0.0008 0.0012 0.0013 0.0015 0.0017 0.0019 0.0051 0.0187 0.0247 0.9432], shape=(10,), dtype=float32)
#
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Encoder Attention Normalized [0.2479 0.1763 0.2770 0.4534 0.3470 0.0000 1.0000 0.5914 0.3678 0.2927]
#
#
#
#
# ~~~~~~~~~~ SEQUENCE BACKTRACE ~~~~~~~~~~
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
#
#
# ~~~~~~~~~~ LABEL BACKTRACE ~~~~~~~~~~
# 3 25    Server returned error NXDOMAIN mitigating pote...
#
#
# ~~~~~~~~~~ PREDICTION BACKTRACE [Top 4] ~~~~~~~~~~
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 17 1    Could not set hostname Method call timed out
# 5 8    ens3 DHCP lease lost
# 26 13    Low random number entropy available <*>
#
#
# ########## END OF INFO FOR LOG SEQUENCE 319 ##########
#
#
#
#
#
#
# ********** ********** ********** ********** **********
#      ********** INPUT SEQUENCE 311 - 320 **********
# ********** ********** ********** ********** **********
#
#
# ---------- ---------- ---------- ---------- ----------
# Input Sequence: (3, 3, 3, 3, 3, 3, 3, 3, 3, 3)
# Label: (3, 3, 3)
#
#
# ^^^^^^^^^^ ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Candidate logs:  tensor([58, 19,  4, 11, 38, 34, 26, 17,  5,  3], device='cuda:0')
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Probabilities:  tf.Tensor([0.0005 0.0009 0.0010 0.0021 0.0035 0.0041 0.0042 0.0180 0.0206 0.9452], shape=(10,), dtype=float32)
#
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Encoder Attention Normalized [0.2719 0.3090 0.4231 0.5175 0.8558 0.9877 1.0000 0.8530 0.0000 0.3515]
#
#
#
#
# ~~~~~~~~~~ SEQUENCE BACKTRACE ~~~~~~~~~~
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
#
#
# ~~~~~~~~~~ LABEL BACKTRACE ~~~~~~~~~~
# 3 25    Server returned error NXDOMAIN mitigating pote...
#
#
# ~~~~~~~~~~ PREDICTION BACKTRACE [Top 4] ~~~~~~~~~~
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 5 8    ens3 DHCP lease lost
# 17 1    Could not set hostname Method call timed out
# 26 13    Low random number entropy available <*>
#
#
# ########## END OF INFO FOR LOG SEQUENCE 320 ##########
#
#
#
#
#
#
# ********** ********** ********** ********** **********
#      ********** INPUT SEQUENCE 312 - 321 **********
# ********** ********** ********** ********** **********
#
#
# ---------- ---------- ---------- ---------- ----------
# Input Sequence: (3, 3, 3, 3, 3, 3, 3, 3, 3, 3)
# Label: (3, 3)
#
#
# ^^^^^^^^^^ ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Candidate logs:  tensor([19, 20,  4, 11, 26, 34, 38, 17,  5,  3], device='cuda:0')
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Probabilities:  tf.Tensor([0.0013 0.0014 0.0028 0.0030 0.0031 0.0031 0.0040 0.0148 0.0181 0.9483], shape=(10,), dtype=float32)
#
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Encoder Attention Normalized [0.0000 0.3942 0.6819 0.6045 0.6065 1.0000 0.4437 0.3383 0.0642 0.4573]
#
#
#
#
# ~~~~~~~~~~ SEQUENCE BACKTRACE ~~~~~~~~~~
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
#
#
# ~~~~~~~~~~ LABEL BACKTRACE ~~~~~~~~~~
# 3 25    Server returned error NXDOMAIN mitigating pote...
#
#
# ~~~~~~~~~~ PREDICTION BACKTRACE [Top 4] ~~~~~~~~~~
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 5 8    ens3 DHCP lease lost
# 17 1    Could not set hostname Method call timed out
# 38 128    [origin software ""rsyslogd"" swVersion ""<*>....
#
#
# ########## END OF INFO FOR LOG SEQUENCE 321 ##########
#
#
#
#
#
#
# ********** ********** ********** ********** **********
#      ********** INPUT SEQUENCE 313 - 322 **********
# ********** ********** ********** ********** **********
#
#
# ---------- ---------- ---------- ---------- ----------
# Input Sequence: (3, 3, 3, 3, 3, 3, 3, 3, 3, 3)
# Label: (3,)
#
#
# ^^^^^^^^^^ ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Candidate logs:  tensor([11, 19, 20,  4, 38, 34, 26, 17,  5,  3], device='cuda:0')
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Probabilities:  tf.Tensor([0.0005 0.0010 0.0017 0.0018 0.0028 0.0037 0.0041 0.0135 0.0246 0.9464], shape=(10,), dtype=float32)
#
#
#
# ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~ ~~~~~~~~~~
# Encoder Attention Normalized [0.0000 0.2776 0.0611 0.3989 0.3502 0.8770 0.5362 0.4713 1.0000 0.4557]
#
#
#
#
# ~~~~~~~~~~ SEQUENCE BACKTRACE ~~~~~~~~~~
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 3 25    Server returned error NXDOMAIN mitigating pote...
#
#
# ~~~~~~~~~~ LABEL BACKTRACE ~~~~~~~~~~
# 3 25    Server returned error NXDOMAIN mitigating pote...
#
#
# ~~~~~~~~~~ PREDICTION BACKTRACE [Top 4] ~~~~~~~~~~
# 3 25    Server returned error NXDOMAIN mitigating pote...
# 5 8    ens3 DHCP lease lost
# 17 1    Could not set hostname Method call timed out
# 26 13    Low random number entropy available <*>
#
#
# ########## END OF INFO FOR LOG SEQUENCE 322 ##########
#
#
#
#
#
#
# ********** ********** ********** ********** **********
#      ********** INPUT SEQUENCE 314 - 323 **********
# ********** ********** ********** ********** **********
# ../Source_Code/Transformer.py:495: RuntimeWarning: invalid value encountered in true_divide
#   normalized_weights =(att-np.min(att))/(np.max(att)-np.min(att))
# ../Source_Code/Transformer.py:495: RuntimeWarning: invalid value encountered in true_divide
#   normalized_weights =(att-np.min(att))/(np.max(att)-np.min(att))
# ../Source_Code/Transformer.py:495: RuntimeWarning: invalid value encountered in true_divide
#   normalized_weights =(att-np.min(att))/(np.max(att)-np.min(att))
